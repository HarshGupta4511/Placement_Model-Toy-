# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.2 KB

# %%
df = df.iloc[:,1:] # row,column

# %%
df
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   cgpa       100 non-null    float64
#  1   iq         100 non-null    float64
#  2   placement  100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
X = df.iloc[:,0:2]

# %%
Y = df.iloc[:,-1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.1)

# %%
X_test
# Out:
#     cgpa     iq
# 84   5.7  169.0
# 16   5.2  224.0
# 43   6.8  141.0
# 69   8.5  120.0
# 8    6.1  156.0
# 89   4.9  151.0
# 57   6.5  130.0
# 39   4.6  146.0
# 1    5.9  106.0
# 47   5.2  161.0

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-1.48308286,  2.00857451],
#        [ 0.00291372,  0.08600949],
#        [ 0.00291372,  0.71843219],
#        [ 0.26514841,  0.18719712],
#        [ 1.13926404, -1.78596171],
#        [-2.18237536,  2.84337247],
#        [-0.17190941,  1.14847963],
#        [-0.60896722,  0.01011876],
#        [ 1.83855655,  1.14847963],
#        [ 0.26514841, -0.44522558],
#        [ 1.31408717,  0.23779094],
#        [ 0.17773685, -0.1922565 ],
#        [-0.52155566, -0.16695959],
#        [ 1.13926404, -0.87527302],
#        [ 2.01337967,  1.19907345],
#        [ 1.13926404,  0.41486929],
#        [ 1.57632186, -0.16695959],
#        [-2.35719849,  1.57852707],
#        [-1.83272911, -0.29344413],
#        [-1.74531755, -1.15353901],
#        [-0.52155566, -0.34403795],
#        [ 0.00291372, -0.47052249],
#        [ 0.61479466,  0.84491673],
#        [-1.04602504,  0.51605693],
#        [-0.78379035,  0.18719712],
#        [-1.1334366 , -0.84997611],
#        [-0.87120191, -0.06577196],
#        [ 0.87702935,  0.46546311],
#        [ 0.61479466,  1.55323016],
#        [ 0.70220623,  0.06071258],
#        [ 1.83855655,  0.71843219],
#        [ 0.09032528, -0.44522558],
#        [-1.74531755, -0.52111631],
#        [-1.04602504,  1.22437035],
#        [ 0.87702935,  1.9832776 ],
#        [-0.78379035,  1.40144871],
#        [ 0.78961779, -0.62230394],
#        [-0.95861348, -1.50769572],
#        [-1.1334366 ,  0.01011876],
#        [ 0.70220623, -0.21755341],
#        [ 1.75114498, -1.05235138],
#        [ 0.09032528,  0.28838475],
#        [ 0.43997154, -0.77408539],
#        [-0.69637879, -0.77408539],
#        [ 1.13926404, -0.11636578],
#        [-1.04602504, -0.21755341],
#        [ 0.09032528, -1.00175756],
#        [ 0.78961779,  0.4401662 ],
#        [-0.69637879,  0.28838475],
#        [ 0.96444091, -1.83655553],
#        [-0.69637879, -0.26814723],
#        [ 0.09032528, -1.40650809],
#        [ 1.40149873,  0.18719712],
#        [-1.39567129,  0.71843219],
#        [-0.25932097,  0.56665074],
#        [-1.1334366 , -1.7353679 ],
#        [-0.95861348,  0.87021364],
#        [ 1.31408717, -1.50769572],
#        [ 1.2266756 ,  0.28838475],
#        [ 0.35255997, -0.11636578],
#        [-0.52155566,  0.36427548],
#        [-0.87120191, -1.45710191],
#        [ 0.43997154, -2.11482152],
#        [-0.95861348,  0.33897857],
#        [ 0.5273831 , -0.01517814],
#        [-0.25932097,  0.28838475],
#        [-0.87120191, -0.74878848],
#        [ 0.43997154,  0.99669818],
#        [-0.25932097,  0.49076002],
#        [-0.95861348, -0.01517814],
#        [ 1.31408717,  0.94610436],
#        [ 1.40149873, -0.7993823 ],
#        [-0.17190941,  0.54135383],
#        [-0.60896722, -0.16695959],
#        [ 0.5273831 ,  0.4401662 ],
#        [ 0.87702935, -1.431805  ],
#        [-0.95861348,  1.90738687],
#        [-1.04602504,  1.0725889 ],
#        [ 0.35255997,  0.51605693],
#        [-0.52155566,  0.46546311],
#        [ 0.87702935,  1.3761518 ],
#        [ 0.78961779,  0.46546311],
#        [ 0.00291372, -1.38121118],
#        [ 0.96444091,  0.76902601],
#        [ 0.00291372, -1.91244625],
#        [-1.39567129, -1.98833698],
#        [ 0.26514841,  0.16190021],
#        [ 0.87702935, -0.21755341],
#        [ 0.70220623, -0.77408539],
#        [-0.78379035, -1.38121118]])

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-0.25932097,  1.22437035],
#        [-0.69637879,  2.6157003 ],
#        [ 0.70220623,  0.51605693],
#        [ 2.1882028 , -0.01517814],
#        [ 0.09032528,  0.89551055],
#        [-0.95861348,  0.76902601],
#        [ 0.43997154,  0.23779094],
#        [-1.22084817,  0.64254147],
#        [-0.08449784, -0.36933486],
#        [-0.69637879,  1.02199509]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
clf.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
y_predict = clf.predict(X_test)

# %%
y_predict
# Out:
# array([0, 0, 1, 1, 1, 0, 1, 0, 0, 0])

# %%
Y_test
# Out:
# 84    0
# 16    0
# 43    1
# 69    1
# 8     0
# 89    0
# 57    1
# 39    0
# 1     0
# 47    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(Y_test,y_predict)
# Out:
# 0.9

# %%
pip install  mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.24.0-py3-none-any.whl.metadata (7.3 kB)
# INFO: pip is looking at multiple versions of mlxtend to determine which version is compatible with other requirements. This could take a while.
#   Downloading mlxtend-0.23.4-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\harshgupta\anaconda3\envs\harsenv\lib\site-packages (from mlxtend) (1.15.3)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\harshgupta\anaconda3\envs\harsenv\lib\site-packages (from mlxtend) (2.2.6)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\harshgupta\anaconda3\envs\harsenv\lib\site-packages (from mlxtend) (2.3.2)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\harshgupta\anaconda3\envs\harsenv\lib\site-packages (from mlxtend) (1.7.2)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\harshgupta\anaconda3\envs\harsenv\lib\site-packages (from mlxtend) (3.10.6)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\harshgupta\anaconda3\envs\harsenv\lib\site-packages (from mlxtend) (1.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\harshgupta\anaconda3\envs\harsenv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\harshgupta\anaconda3\envs\harsenv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\harshgupta\anaconda3\envs\harsenv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\harshgupta\anaconda3\envs\harsenv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\harshgupta\anaconda3\envs\harsenv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\harshgupta\anaconda3\envs\harsenv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\harshgupta\anaconda3\envs\harsenv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\harshgupta\anaconda3\envs\harsenv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\harshgupta\anaconda3\envs\harsenv\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\harshgupta\anaconda3\envs\harsenv\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\harshgupta\anaconda3\envs\harsenv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\harshgupta\anaconda3\envs\harsenv\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)
# Downloading mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 17.3 MB/s eta 0:00:00
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.4
# Note: you may need to restart the kernel to use updated packages.

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train,Y_train.values,clf=clf ,legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb')) #wb = write_binary
